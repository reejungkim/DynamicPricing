# %%
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
# %matplotlib inline

# %%
df = pd.read_csv('/Users/reejungkim/Documents/Git/Dynamic Pricing Optimization/Airbnb-Dynamic-Pricing-Optimization/Airbnb_data/listings_SanFan.csv')

# %%
df.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  13824783  https://www.airbnb.com/rooms/13824783  20170510102046
# 1  16740225  https://www.airbnb.com/rooms/16740225  20170510102046
# 2  18125245  https://www.airbnb.com/rooms/18125245  20170510102046
# 3   8362570   https://www.airbnb.com/rooms/8362570  20170510102046
# 4    789867    https://www.airbnb.com/rooms/789867  20170510102046
#
#   last_scraped                                               name  \
# 0   2017-05-10      Full floor of a city cottage (up to 4 guests)
# 1   2017-05-10                    Guest Room of Two Bedroom Condo
# 2   2017-05-10           Cozy, spacious 2 flat in Lincoln Square!
# 3   2017-05-10                          Lincoln Square Ravenswood
# 4   2017-05-10  Cozy Private Room in a Classic Chicago Appartm...
#
#                                              summary  \
# 0  This 3rd-floor garrett apartment (built-out at...
# 1  Warm and secure room in a Two Bedroom Condo lo...
# 2  This cute, spacious 2 flat in Lincoln Square i...
# 3  Lincoln square, Ravenswood and Andersonville g...
# 4  $40 OFF COUPON FOR ALL NEW AIRBNB GUESTS - VIS...
#
#                                                space  \
# 0  This is more of an apartment or flat than a ro...
# 1                                                NaN
# 2  This cute, spacious 2 flat in Lincoln Square i...
# 3  Large living room and kitchen. In unit washer ...
# 4  A little bit about the building. It's a classi...
#
#                                          description experiences_offered  \
# 0  This 3rd-floor garrett apartment (built-out at...                none
# 1  Warm and secure room in a Two Bedroom Condo lo...                none
# 2  This cute, spacious 2 flat in Lincoln Square i...                none
# 3  Lincoln square, Ravenswood and Andersonville g...                none
# 4  $40 OFF COUPON FOR ALL NEW AIRBNB GUESTS - VIS...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0  This quiet corner of a neighborhood (Bowmanvil...  ...                10.0
# 1                                                NaN  ...                 NaN
# 2  Lincoln Square is a quickly growing Chicago ne...  ...                10.0
# 3  Great family neighborhood with a beautiful par...  ...                10.0
# 4  The neighborhood is on the north-side of Chica...  ...                 9.0
#
#   requires_license                    license  \
# 0                t  City registration pending
# 1                t  City registration pending
# 2                t  City registration pending
# 3                t  City registration pending
# 4                t  City registration pending
#
#                          jurisdiction_names instant_bookable  \
# 0  Illinois State, Cook County, IL, CHICAGO                t
# 1  Illinois State, Cook County, IL, CHICAGO                t
# 2  Illinois State, Cook County, IL, CHICAGO                f
# 3  Illinois State, Cook County, IL, CHICAGO                f
# 4  Illinois State, Cook County, IL, CHICAGO                t
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1              strict                             f
# 2            moderate                             f
# 3            flexible                             f
# 4              strict                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              3
# 2                                f                              1
# 3                                f                              1
# 4                                f                              1
#
#    reviews_per_month
# 0               2.57
# 1                NaN
# 2               4.00
# 3               0.87
# 4               1.96
#
# [5 rows x 95 columns]

# %%
# FEES and PRICES
df['price'] = df['price'].str.replace("\$|,", "").astype(float)
df['security_deposit'] = df['security_deposit'].str.replace("\$|,", "").astype(float)
df['cleaning_fee'] = df['cleaning_fee'].str.replace("\$|,", "").astype(float)
df['extra_people'] = df['extra_people'].str.replace("\$|,", "").astype(float)
df['availability'] = df['availability_365'] / 365
# Out:
# /var/folders/l6/22wjv97x2yq_lzg77lp74ml40000gn/T/ipykernel_1225/1825163915.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['price'] = df['price'].str.replace("\$|,", "").astype(float)
# /var/folders/l6/22wjv97x2yq_lzg77lp74ml40000gn/T/ipykernel_1225/1825163915.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['security_deposit'] = df['security_deposit'].str.replace("\$|,", "").astype(float)
# /var/folders/l6/22wjv97x2yq_lzg77lp74ml40000gn/T/ipykernel_1225/1825163915.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['cleaning_fee'] = df['cleaning_fee'].str.replace("\$|,", "").astype(float)
# /var/folders/l6/22wjv97x2yq_lzg77lp74ml40000gn/T/ipykernel_1225/1825163915.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['extra_people'] = df['extra_people'].str.replace("\$|,", "").astype(float)

# %%
df.head(3)
# Out:
#          id                            listing_url       scrape_id  \
# 0  13824783  https://www.airbnb.com/rooms/13824783  20170510102046
# 1  16740225  https://www.airbnb.com/rooms/16740225  20170510102046
# 2  18125245  https://www.airbnb.com/rooms/18125245  20170510102046
#
#   last_scraped                                           name  \
# 0   2017-05-10  Full floor of a city cottage (up to 4 guests)
# 1   2017-05-10                Guest Room of Two Bedroom Condo
# 2   2017-05-10       Cozy, spacious 2 flat in Lincoln Square!
#
#                                              summary  \
# 0  This 3rd-floor garrett apartment (built-out at...
# 1  Warm and secure room in a Two Bedroom Condo lo...
# 2  This cute, spacious 2 flat in Lincoln Square i...
#
#                                                space  \
# 0  This is more of an apartment or flat than a ro...
# 1                                                NaN
# 2  This cute, spacious 2 flat in Lincoln Square i...
#
#                                          description experiences_offered  \
# 0  This 3rd-floor garrett apartment (built-out at...                none
# 1  Warm and secure room in a Two Bedroom Condo lo...                none
# 2  This cute, spacious 2 flat in Lincoln Square i...                none
#
#                                neighborhood_overview  ... requires_license  \
# 0  This quiet corner of a neighborhood (Bowmanvil...  ...                t
# 1                                                NaN  ...                t
# 2  Lincoln Square is a quickly growing Chicago ne...  ...                t
#
#                      license                        jurisdiction_names  \
# 0  City registration pending  Illinois State, Cook County, IL, CHICAGO
# 1  City registration pending  Illinois State, Cook County, IL, CHICAGO
# 2  City registration pending  Illinois State, Cook County, IL, CHICAGO
#
#   instant_bookable cancellation_policy require_guest_profile_picture  \
# 0                t            moderate                             f
# 1                t              strict                             f
# 2                f            moderate                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              3
# 2                                f                              1
#
#   reviews_per_month  availability
# 0              2.57      0.087671
# 1               NaN      0.000000
# 2              4.00      0.432877
#
# [3 rows x 96 columns]
